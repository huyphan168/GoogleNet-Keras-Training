# %%
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Concatenate, Lambda, Dense, Activation, Input, AveragePooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.nn import local_response_normalization
from IPython.display import SVG
import IPython
from tensorflow.keras.utils import model_to_dot
from tensorflow.keras.utils import plot_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt 
import sklearn 
from tensorflow.keras.applications import imagenet_utils
import random
from imutils import paths
import os
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import numpy as np
from tensorflow.keras import models
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# *Today i will implement the InceptionNet version 1 based on this wonderful and  specific architecture from medium*
#
#
# ![alt text](https://mk0learnfx6ydjq1jij.kinstacdn.com/wp-content/uploads/2019/09/1_53uKkbeyzJcdo8PE5TQqqw-1-1024x700.png)
#
# Mong la khong fail :v

# %%
def LocResNorm(X):
  X = local_response_normalization(X)
  return X
def Inception_module(X, filters):
  X_conv1 = X
  X_conv3 = X
  X_conv5 = X
  X_pool = X
  F1_conv1_1, F1_conv1_3, F2_conv3, F1_conv1_5, F2_conv5, F2_conv1 = filters
  X_conv1 = Conv2D(F1_conv1_1, kernel_size = (1,1), padding = "same", kernel_initializer = glorot_uniform(seed = 0))(X_conv1)
  X_conv1 = Activation("relu")(X_conv1)
  X_conv3 = Conv2D(F1_conv1_3, kernel_size=(1,1), padding = "same", kernel_initializer= glorot_uniform(seed = 0))(X_conv3)
  X_conv3 = Activation("relu")(X_conv3)
  X_conv3 = Conv2D(F2_conv3, kernel_size= (3,3), padding = "same", kernel_initializer = glorot_uniform(seed = 0))(X_conv3)
  X_conv3 = Activation("relu")(X_conv3)
  X_conv5 = Conv2D(F1_conv1_5, kernel_size=(1,1), padding = "same", kernel_initializer= glorot_uniform(seed = 0))(X_conv5)
  X_conv5 = Activation("relu")(X_conv5)
  X_conv5 = Conv2D(F2_conv5, kernel_size= (5,5), padding = "same", kernel_initializer = glorot_uniform(seed = 0))(X_conv5)
  X_conv5 = Activation("relu")(X_conv5)
  X_pool = MaxPooling2D(pool_size=(3,3), padding = "same", strides = (1,1))(X_pool)
  X_pool = Activation("relu")(X_pool)
  X_pool = Conv2D(F2_conv1, kernel_size= (1,1), padding = "same", kernel_initializer = glorot_uniform(seed = 0))(X_pool)
  X_pool = Activation("relu")(X_pool)
  X = Concatenate(axis = 3)([X_conv1, X_conv3, X_conv5, X_pool])
  return X
def Stem_module(X, filters):
  F_conv7, F_conv1, F_conv3 = filters
  X = Conv2D(F_conv7, kernel_size = (7,7), strides = (2,2), kernel_initializer= glorot_uniform(seed = 0), padding = "same")(X)
  X = Activation("relu")(X)
  X = MaxPooling2D(pool_size = (3,3), strides = (2,2), padding= "same")(X)
  X = LocResNorm(X)
  X = Conv2D(F_conv1, kernel_size=(1,1), padding = "valid", strides = (1,1), kernel_initializer=glorot_uniform(seed = 0))(X)
  X = Activation("relu")(X)
  X = Conv2D(F_conv3, kernel_size=(3,3), kernel_initializer = glorot_uniform(seed = 0), strides = (1,1), padding = "same")(X)
  X = Activation("relu")(X)
  X = LocResNorm(X)
  X = MaxPooling2D(pool_size = (3,3), strides = (2,2), padding = "valid")(X)
  return X
def Auxiliary_module(X, filter, classes, name):
  X = AveragePooling2D(pool_size = (5,5), strides = (3,3), padding = "valid")(X)
  X = Conv2D(filter, kernel_size = (1,1), strides = (1,1), padding = "same", kernel_initializer = glorot_uniform(seed = 0))(X)
  X = Flatten()(X)
  X = Dense(512, activation = "relu", kernel_initializer = glorot_uniform(seed = 0))(X)
  X = Dropout(0.2)(X)
  X = Dense(classes, kernel_initializer = glorot_uniform(seed = 0), kernel_regularizer = "l1")(X)
  X = Activation("softmax", name = name)(X)
  return X

# %%
def GoogleNet_v1(input_shape, classes):
  X_input = Input(input_shape, sparse = False)
  X = Stem_module(X_input, [64,64,192])
  X = Inception_module(X, [64, 96, 128, 16, 32, 32])
  X = Inception_module(X, [128, 128, 192, 32, 96, 64])
  X = MaxPooling2D(pool_size = (3,3), strides = (2,2), padding = "same")(X)
  X = Inception_module(X, [192, 96, 208, 16, 48, 64])
  X_aux1 = X
  softmax_0 = Auxiliary_module(X_aux1, 128, 10, "aux1")
  X = Inception_module(X, [160, 112, 224, 24, 64, 64])
  X = Inception_module(X, [128, 128, 256, 24, 64, 64])
  X = Inception_module(X, [112, 144, 288, 32, 64, 64])
  X_aux2 = X
  softmax_1 = Auxiliary_module(X_aux2, 128, 10, "aux2")
  X = Inception_module(X, [256, 160, 320, 32, 128, 128])
  X = MaxPooling2D(pool_size=(3,3), strides = (2,2), padding = "same")(X)
  X = Inception_module(X, [256, 160, 320, 32, 128, 128])
  X = Inception_module(X, [384, 192, 384, 48, 128, 128])
  X = AveragePooling2D(pool_size = (7,7), strides = (1,1), padding = "valid")(X)
  X = Flatten()(X)
  X = Dense(512, activation = "relu", kernel_initializer = glorot_uniform(seed = 0))(X)
  X = Dropout(0.2)(X)
  X = Dense(classes, kernel_initializer = glorot_uniform(seed = 0))(X)
  softmax_2 = Activation("softmax", name = "main")(X)
  model = Model(inputs = X_input, outputs = [softmax_0, softmax_1, softmax_2], name = "GoogleNet_v1")
  return model

# %%
import tensorflow as tf
print("Tensorflow version " + tf.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
# Out:
# Tensorflow version 2.2.0
# Running on TPU  ['10.69.196.234:8470']
# INFO:tensorflow:Initializing the TPU system: grpc://10.69.196.234:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.69.196.234:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %%
with tpu_strategy.scope():
  model = GoogleNet_v1((224,224,3), 10)

# %%
losses = {"aux1": "categorical_crossentropy", "aux2": "categorical_crossentropy", "main": "categorical_crossentropy"}
losses_weight = {"aux1": 0.3, "aux2": 0.3, "main": 1.0}

# %%
model.compile(optimizer= "adam", loss = losses, loss_weights = losses_weight, metrics = ["accuracy"])

# %%
image_path = list(paths.list_images("/content/drive/My Drive/Colab datasets/10-monkey-species"))
random.shuffle(image_path)
print(image_path[0])
# Out:
# /content/drive/My Drive/Colab datasets/10-monkey-species/training/training/n1/n1118.jpg

# %%
label = [p.split(os.path.sep)[-2] for p in image_path]
list_image = []
for path in image_path:
  image = load_img(path, target_size = (224,224,3))
  image_tensor = img_to_array(image)
  image_tensor.reshape(1, 224, 224, 3)
  list_image.append(image_tensor)
data = np.asarray(list_image)
print(data.shape)
# Out:
# (1377, 224, 224, 3)

# %%
LE = LabelEncoder()
Label = LE.fit_transform(label)
OHE = OneHotEncoder(sparse = False)
Label = OHE.fit_transform(Label.reshape(-1, 1))
print(Label.shape)
# Out:
# (1377, 10)

# %%
image = load_img(image_path[0], target_size = (224,224,3))
IPython.display.display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F54E9AF8710>

# %%
#Prepared data
X_train_orig, X_test_orig, y_train_orig, y_test_orig = train_test_split(data, Label, test_size = 0.2)
X_train = X_train_orig/255.0
X_test = X_test_orig/255.0
print("Number of training examples:  " + str(X_train.shape[0]))
print("Number of test examples:  " + str(X_test.shape[0]))
print("Dimension of training sample:  " + str(X_train.shape))
print("Dimension of label:  " + str(y_train_orig.shape))
# Out:
# Number of training examples:  1101
# Number of test examples:  276
# Dimension of training sample:  (1101, 224, 224, 3)
# Dimension of label:  (1101, 10)

# %%
tsb = TensorBoard(log_dir = "./log")
stop = EarlyStopping(patience = 5)

# %%
#Training step
model.fit(x = X_train, y = [y_train_orig,y_train_orig,y_train_orig], validation_data = (X_test, [y_test_orig, y_test_orig,y_test_orig]), epochs = 100, batch_size = 32, verbose = 2)
# Out:
# Epoch 1/100
# 35/35 - 32s - loss: 7.6416 - aux2_loss: 2.3043 - main_loss: 2.3043 - aux1_accuracy: 0.1163 - aux1_loss: 2.3013 - main_accuracy: 0.0963 - aux2_accuracy: 0.1035 - val_loss: 6.2005 - val_aux2_loss: 2.3011 - val_main_loss: 2.3027 - val_aux1_accuracy: 0.1196 - val_aux1_loss: 2.2829 - val_main_accuracy: 0.1123 - val_aux2_accuracy: 0.0978
# Epoch 2/100
# 35/35 - 6s - loss: 5.2470 - aux2_loss: 2.3055 - main_loss: 2.3026 - aux1_accuracy: 0.1435 - aux1_loss: 2.2867 - main_accuracy: 0.1008 - aux2_accuracy: 0.1172 - val_loss: 4.3892 - val_aux2_loss: 2.2970 - val_main_loss: 2.3001 - val_aux1_accuracy: 0.1812 - val_aux1_loss: 2.2629 - val_main_accuracy: 0.0978 - val_aux2_accuracy: 0.2029
# Epoch 3/100
# 35/35 - 6s - loss: 3.9636 - aux2_loss: 2.2627 - main_loss: 2.2773 - aux1_accuracy: 0.1817 - aux1_loss: 2.2582 - main_accuracy: 0.1644 - aux2_accuracy: 0.1835 - val_loss: 3.6154 - val_aux2_loss: 2.2266 - val_main_loss: 2.1850 - val_aux1_accuracy: 0.1848 - val_aux1_loss: 2.2227 - val_main_accuracy: 0.1884 - val_aux2_accuracy: 0.1848
# Epoch 4/100
# 35/35 - 6s - loss: 3.7577 - aux2_loss: 2.2754 - main_loss: 2.3246 - aux1_accuracy: 0.1453 - aux1_loss: 2.2663 - main_accuracy: 0.1435 - aux2_accuracy: 0.1390 - val_loss: 3.6765 - val_aux2_loss: 2.2771 - val_main_loss: 2.2603 - val_aux1_accuracy: 0.1486 - val_aux1_loss: 2.2844 - val_main_accuracy: 0.1123 - val_aux2_accuracy: 0.1304
# Epoch 5/100
# 35/35 - 6s - loss: 3.5568 - aux2_loss: 2.2419 - main_loss: 2.1785 - aux1_accuracy: 0.1708 - aux1_loss: 2.2183 - main_accuracy: 0.1644 - aux2_accuracy: 0.1817 - val_loss: 3.3982 - val_aux2_loss: 2.2106 - val_main_loss: 2.0508 - val_aux1_accuracy: 0.1993 - val_aux1_loss: 2.1045 - val_main_accuracy: 0.2283 - val_aux2_accuracy: 0.1957
# Epoch 6/100
# 35/35 - 6s - loss: 3.4612 - aux2_loss: 2.2076 - main_loss: 2.1128 - aux1_accuracy: 0.1907 - aux1_loss: 2.1300 - main_accuracy: 0.1944 - aux2_accuracy: 0.1907 - val_loss: 3.3577 - val_aux2_loss: 2.1762 - val_main_loss: 2.0426 - val_aux1_accuracy: 0.1993 - val_aux1_loss: 2.0526 - val_main_accuracy: 0.2210 - val_aux2_accuracy: 0.1993
# Epoch 7/100
# 35/35 - 6s - loss: 3.4073 - aux2_loss: 2.1490 - main_loss: 2.0796 - aux1_accuracy: 0.1862 - aux1_loss: 2.1134 - main_accuracy: 0.1998 - aux2_accuracy: 0.1826 - val_loss: 3.3726 - val_aux2_loss: 2.0904 - val_main_loss: 2.0603 - val_aux1_accuracy: 0.1522 - val_aux1_loss: 2.0991 - val_main_accuracy: 0.2065 - val_aux2_accuracy: 0.1920
# Epoch 8/100
# 35/35 - 6s - loss: 3.3361 - aux2_loss: 2.0769 - main_loss: 2.0375 - aux1_accuracy: 0.2180 - aux1_loss: 2.0706 - main_accuracy: 0.2125 - aux2_accuracy: 0.1935 - val_loss: 3.2444 - val_aux2_loss: 2.0416 - val_main_loss: 1.9791 - val_aux1_accuracy: 0.2174 - val_aux1_loss: 2.0003 - val_main_accuracy: 0.2645 - val_aux2_accuracy: 0.2065
# Epoch 9/100
# 35/35 - 6s - loss: 3.2489 - aux2_loss: 2.0387 - main_loss: 1.9813 - aux1_accuracy: 0.2243 - aux1_loss: 2.0053 - main_accuracy: 0.2443 - aux2_accuracy: 0.1953 - val_loss: 3.2264 - val_aux2_loss: 2.0087 - val_main_loss: 1.9518 - val_aux1_accuracy: 0.2246 - val_aux1_loss: 2.0457 - val_main_accuracy: 0.2464 - val_aux2_accuracy: 0.2283
# Epoch 10/100
# 35/35 - 6s - loss: 3.1188 - aux2_loss: 1.9671 - main_loss: 1.8899 - aux1_accuracy: 0.2543 - aux1_loss: 1.9276 - main_accuracy: 0.2579 - aux2_accuracy: 0.2316 - val_loss: 3.1030 - val_aux2_loss: 1.9279 - val_main_loss: 1.8939 - val_aux1_accuracy: 0.2609 - val_aux1_loss: 1.8994 - val_main_accuracy: 0.2717 - val_aux2_accuracy: 0.2862
# Epoch 11/100
# 35/35 - 6s - loss: 3.0278 - aux2_loss: 1.8767 - main_loss: 1.8536 - aux1_accuracy: 0.2925 - aux1_loss: 1.8267 - main_accuracy: 0.2716 - aux2_accuracy: 0.2861 - val_loss: 3.0042 - val_aux2_loss: 1.9295 - val_main_loss: 1.8131 - val_aux1_accuracy: 0.2790 - val_aux1_loss: 1.8256 - val_main_accuracy: 0.2935 - val_aux2_accuracy: 0.2536
# Epoch 12/100
# 35/35 - 6s - loss: 2.9516 - aux2_loss: 1.8450 - main_loss: 1.8038 - aux1_accuracy: 0.2906 - aux1_loss: 1.7604 - main_accuracy: 0.2761 - aux2_accuracy: 0.2825 - val_loss: 2.8339 - val_aux2_loss: 1.7879 - val_main_loss: 1.7180 - val_aux1_accuracy: 0.3297 - val_aux1_loss: 1.7041 - val_main_accuracy: 0.3370 - val_aux2_accuracy: 0.2899
# Epoch 13/100
# 35/35 - 6s - loss: 2.9966 - aux2_loss: 1.8736 - main_loss: 1.8430 - aux1_accuracy: 0.3306 - aux1_loss: 1.7392 - main_accuracy: 0.2825 - aux2_accuracy: 0.2734 - val_loss: 2.8759 - val_aux2_loss: 1.7978 - val_main_loss: 1.7593 - val_aux1_accuracy: 0.3514 - val_aux1_loss: 1.6957 - val_main_accuracy: 0.2971 - val_aux2_accuracy: 0.3188
# Epoch 14/100
# 35/35 - 6s - loss: 2.8471 - aux2_loss: 1.7953 - main_loss: 1.7359 - aux1_accuracy: 0.3551 - aux1_loss: 1.6763 - main_accuracy: 0.3279 - aux2_accuracy: 0.2879 - val_loss: 2.8269 - val_aux2_loss: 1.7937 - val_main_loss: 1.7225 - val_aux1_accuracy: 0.3442 - val_aux1_loss: 1.6493 - val_main_accuracy: 0.3261 - val_aux2_accuracy: 0.2899
# Epoch 15/100
# 35/35 - 6s - loss: 2.8092 - aux2_loss: 1.7600 - main_loss: 1.7138 - aux1_accuracy: 0.3678 - aux1_loss: 1.6395 - main_accuracy: 0.3134 - aux2_accuracy: 0.3034 - val_loss: 2.7838 - val_aux2_loss: 1.7265 - val_main_loss: 1.7000 - val_aux1_accuracy: 0.3478 - val_aux1_loss: 1.6227 - val_main_accuracy: 0.3116 - val_aux2_accuracy: 0.3116
# Epoch 16/100
# 35/35 - 6s - loss: 2.8010 - aux2_loss: 1.7482 - main_loss: 1.7179 - aux1_accuracy: 0.3769 - aux1_loss: 1.5981 - main_accuracy: 0.3025 - aux2_accuracy: 0.3052 - val_loss: 2.8083 - val_aux2_loss: 1.7674 - val_main_loss: 1.7177 - val_aux1_accuracy: 0.3696 - val_aux1_loss: 1.6161 - val_main_accuracy: 0.2754 - val_aux2_accuracy: 0.2971
# Epoch 17/100
# 35/35 - 6s - loss: 2.9251 - aux2_loss: 1.8259 - main_loss: 1.8032 - aux1_accuracy: 0.3697 - aux1_loss: 1.6676 - main_accuracy: 0.2707 - aux2_accuracy: 0.2934 - val_loss: 2.8261 - val_aux2_loss: 1.7563 - val_main_loss: 1.7340 - val_aux1_accuracy: 0.3949 - val_aux1_loss: 1.6432 - val_main_accuracy: 0.3514 - val_aux2_accuracy: 0.3297
# Epoch 18/100
# 35/35 - 6s - loss: 2.7430 - aux2_loss: 1.7071 - main_loss: 1.6846 - aux1_accuracy: 0.4160 - aux1_loss: 1.5719 - main_accuracy: 0.3515 - aux2_accuracy: 0.3451 - val_loss: 2.7429 - val_aux2_loss: 1.6991 - val_main_loss: 1.6682 - val_aux1_accuracy: 0.3804 - val_aux1_loss: 1.6326 - val_main_accuracy: 0.3370 - val_aux2_accuracy: 0.3225
# Epoch 19/100
# 35/35 - 6s - loss: 2.6383 - aux2_loss: 1.6576 - main_loss: 1.6093 - aux1_accuracy: 0.3996 - aux1_loss: 1.5170 - main_accuracy: 0.3560 - aux2_accuracy: 0.3515 - val_loss: 2.7132 - val_aux2_loss: 1.6873 - val_main_loss: 1.6653 - val_aux1_accuracy: 0.3804 - val_aux1_loss: 1.5445 - val_main_accuracy: 0.3333 - val_aux2_accuracy: 0.3333
# Epoch 20/100
# 35/35 - 6s - loss: 2.5803 - aux2_loss: 1.5940 - main_loss: 1.5787 - aux1_accuracy: 0.4296 - aux1_loss: 1.4811 - main_accuracy: 0.3642 - aux2_accuracy: 0.3860 - val_loss: 2.6473 - val_aux2_loss: 1.6157 - val_main_loss: 1.6373 - val_aux1_accuracy: 0.4275 - val_aux1_loss: 1.4893 - val_main_accuracy: 0.3406 - val_aux2_accuracy: 0.3696
# Epoch 21/100
# 35/35 - 6s - loss: 2.6401 - aux2_loss: 1.6380 - main_loss: 1.6238 - aux1_accuracy: 0.4133 - aux1_loss: 1.4838 - main_accuracy: 0.3642 - aux2_accuracy: 0.3697 - val_loss: 2.6484 - val_aux2_loss: 1.5879 - val_main_loss: 1.6326 - val_aux1_accuracy: 0.3913 - val_aux1_loss: 1.5255 - val_main_accuracy: 0.3225 - val_aux2_accuracy: 0.3732
# Epoch 22/100
# 35/35 - 6s - loss: 2.4454 - aux2_loss: 1.5202 - main_loss: 1.4886 - aux1_accuracy: 0.4523 - aux1_loss: 1.4113 - main_accuracy: 0.4124 - aux2_accuracy: 0.4369 - val_loss: 2.5930 - val_aux2_loss: 1.5994 - val_main_loss: 1.5882 - val_aux1_accuracy: 0.4601 - val_aux1_loss: 1.4906 - val_main_accuracy: 0.3877 - val_aux2_accuracy: 0.3659
# Epoch 23/100
# 35/35 - 6s - loss: 2.3997 - aux2_loss: 1.4842 - main_loss: 1.4606 - aux1_accuracy: 0.4759 - aux1_loss: 1.3726 - main_accuracy: 0.4278 - aux2_accuracy: 0.4178 - val_loss: 2.6190 - val_aux2_loss: 1.5679 - val_main_loss: 1.6062 - val_aux1_accuracy: 0.4457 - val_aux1_loss: 1.5315 - val_main_accuracy: 0.4022 - val_aux2_accuracy: 0.4094
# Epoch 24/100
# 35/35 - 6s - loss: 2.3614 - aux2_loss: 1.4693 - main_loss: 1.4217 - aux1_accuracy: 0.4741 - aux1_loss: 1.3860 - main_accuracy: 0.4487 - aux2_accuracy: 0.4360 - val_loss: 2.5586 - val_aux2_loss: 1.5395 - val_main_loss: 1.5794 - val_aux1_accuracy: 0.4710 - val_aux1_loss: 1.4418 - val_main_accuracy: 0.4348 - val_aux2_accuracy: 0.4275
# Epoch 25/100
# 35/35 - 6s - loss: 2.3232 - aux2_loss: 1.4476 - main_loss: 1.4016 - aux1_accuracy: 0.4932 - aux1_loss: 1.3473 - main_accuracy: 0.4423 - aux2_accuracy: 0.4441 - val_loss: 2.5267 - val_aux2_loss: 1.5609 - val_main_loss: 1.5304 - val_aux1_accuracy: 0.4312 - val_aux1_loss: 1.4868 - val_main_accuracy: 0.3841 - val_aux2_accuracy: 0.4420
# Epoch 26/100
# 35/35 - 6s - loss: 2.2895 - aux2_loss: 1.4322 - main_loss: 1.3829 - aux1_accuracy: 0.5114 - aux1_loss: 1.3110 - main_accuracy: 0.4605 - aux2_accuracy: 0.4378 - val_loss: 2.4497 - val_aux2_loss: 1.5276 - val_main_loss: 1.4683 - val_aux1_accuracy: 0.4565 - val_aux1_loss: 1.4684 - val_main_accuracy: 0.4493 - val_aux2_accuracy: 0.4420
# Epoch 27/100
# 35/35 - 6s - loss: 2.1607 - aux2_loss: 1.3716 - main_loss: 1.2884 - aux1_accuracy: 0.5304 - aux1_loss: 1.2422 - main_accuracy: 0.5023 - aux2_accuracy: 0.4805 - val_loss: 2.4594 - val_aux2_loss: 1.4514 - val_main_loss: 1.5103 - val_aux1_accuracy: 0.4638 - val_aux1_loss: 1.3906 - val_main_accuracy: 0.4130 - val_aux2_accuracy: 0.4348
# Epoch 28/100
# 35/35 - 6s - loss: 2.1367 - aux2_loss: 1.3612 - main_loss: 1.2638 - aux1_accuracy: 0.5286 - aux1_loss: 1.2415 - main_accuracy: 0.4986 - aux2_accuracy: 0.4796 - val_loss: 2.4709 - val_aux2_loss: 1.5075 - val_main_loss: 1.4981 - val_aux1_accuracy: 0.4638 - val_aux1_loss: 1.4290 - val_main_accuracy: 0.4275 - val_aux2_accuracy: 0.4638
# Epoch 29/100
# 35/35 - 6s - loss: 2.0675 - aux2_loss: 1.2974 - main_loss: 1.2077 - aux1_accuracy: 0.5431 - aux1_loss: 1.2462 - main_accuracy: 0.5486 - aux2_accuracy: 0.5477 - val_loss: 2.6229 - val_aux2_loss: 1.5657 - val_main_loss: 1.6047 - val_aux1_accuracy: 0.4638 - val_aux1_loss: 1.5162 - val_main_accuracy: 0.4312 - val_aux2_accuracy: 0.4565
# Epoch 30/100
# 35/35 - 6s - loss: 2.2071 - aux2_loss: 1.3687 - main_loss: 1.3193 - aux1_accuracy: 0.5150 - aux1_loss: 1.2809 - main_accuracy: 0.4959 - aux2_accuracy: 0.4832 - val_loss: 2.3651 - val_aux2_loss: 1.4230 - val_main_loss: 1.4262 - val_aux1_accuracy: 0.4529 - val_aux1_loss: 1.3941 - val_main_accuracy: 0.4601 - val_aux2_accuracy: 0.4638
# Epoch 31/100
# 35/35 - 6s - loss: 1.9694 - aux2_loss: 1.2349 - main_loss: 1.1461 - aux1_accuracy: 0.5595 - aux1_loss: 1.1916 - main_accuracy: 0.5540 - aux2_accuracy: 0.5313 - val_loss: 2.4411 - val_aux2_loss: 1.4801 - val_main_loss: 1.4954 - val_aux1_accuracy: 0.5072 - val_aux1_loss: 1.3598 - val_main_accuracy: 0.4746 - val_aux2_accuracy: 0.4783
# Epoch 32/100
# 35/35 - 6s - loss: 2.0536 - aux2_loss: 1.3014 - main_loss: 1.2096 - aux1_accuracy: 0.5531 - aux1_loss: 1.1975 - main_accuracy: 0.5223 - aux2_accuracy: 0.5186 - val_loss: 2.4510 - val_aux2_loss: 1.4336 - val_main_loss: 1.5300 - val_aux1_accuracy: 0.5036 - val_aux1_loss: 1.3335 - val_main_accuracy: 0.4348 - val_aux2_accuracy: 0.4819
# Epoch 33/100
# 35/35 - 6s - loss: 1.8956 - aux2_loss: 1.2291 - main_loss: 1.1011 - aux1_accuracy: 0.5813 - aux1_loss: 1.1089 - main_accuracy: 0.5749 - aux2_accuracy: 0.5295 - val_loss: 2.7211 - val_aux2_loss: 1.5780 - val_main_loss: 1.7286 - val_aux1_accuracy: 0.5217 - val_aux1_loss: 1.4086 - val_main_accuracy: 0.4130 - val_aux2_accuracy: 0.4529
# Epoch 34/100
# 35/35 - 6s - loss: 1.7971 - aux2_loss: 1.1357 - main_loss: 1.0404 - aux1_accuracy: 0.6067 - aux1_loss: 1.0607 - main_accuracy: 0.5940 - aux2_accuracy: 0.5668 - val_loss: 2.3922 - val_aux2_loss: 1.3909 - val_main_loss: 1.4945 - val_aux1_accuracy: 0.5507 - val_aux1_loss: 1.2779 - val_main_accuracy: 0.4928 - val_aux2_accuracy: 0.4928
# Epoch 35/100
# 35/35 - 6s - loss: 1.6044 - aux2_loss: 1.0595 - main_loss: 0.9025 - aux1_accuracy: 0.6630 - aux1_loss: 0.9495 - main_accuracy: 0.6540 - aux2_accuracy: 0.6158 - val_loss: 2.3320 - val_aux2_loss: 1.3538 - val_main_loss: 1.4613 - val_aux1_accuracy: 0.5797 - val_aux1_loss: 1.2246 - val_main_accuracy: 0.5399 - val_aux2_accuracy: 0.5217
# Epoch 36/100
# 35/35 - 6s - loss: 1.4488 - aux2_loss: 0.9400 - main_loss: 0.8072 - aux1_accuracy: 0.6785 - aux1_loss: 0.8745 - main_accuracy: 0.6975 - aux2_accuracy: 0.6449 - val_loss: 2.5791 - val_aux2_loss: 1.4410 - val_main_loss: 1.6565 - val_aux1_accuracy: 0.5616 - val_aux1_loss: 1.3086 - val_main_accuracy: 0.5072 - val_aux2_accuracy: 0.5181
# Epoch 37/100
# 35/35 - 6s - loss: 1.6286 - aux2_loss: 1.0513 - main_loss: 0.9281 - aux1_accuracy: 0.6567 - aux1_loss: 0.9505 - main_accuracy: 0.6667 - aux2_accuracy: 0.6167 - val_loss: 2.4576 - val_aux2_loss: 1.3901 - val_main_loss: 1.5320 - val_aux1_accuracy: 0.5543 - val_aux1_loss: 1.3550 - val_main_accuracy: 0.4855 - val_aux2_accuracy: 0.5616
# Epoch 38/100
# 35/35 - 6s - loss: 1.4804 - aux2_loss: 0.9777 - main_loss: 0.8155 - aux1_accuracy: 0.6930 - aux1_loss: 0.8873 - main_accuracy: 0.7012 - aux2_accuracy: 0.6540 - val_loss: 2.3851 - val_aux2_loss: 1.3960 - val_main_loss: 1.4874 - val_aux1_accuracy: 0.5978 - val_aux1_loss: 1.2554 - val_main_accuracy: 0.5254 - val_aux2_accuracy: 0.5507
# Epoch 39/100
# 35/35 - 6s - loss: 1.3858 - aux2_loss: 0.9401 - main_loss: 0.7642 - aux1_accuracy: 0.7275 - aux1_loss: 0.7811 - main_accuracy: 0.7321 - aux2_accuracy: 0.6567 - val_loss: 2.2175 - val_aux2_loss: 1.3189 - val_main_loss: 1.3627 - val_aux1_accuracy: 0.5725 - val_aux1_loss: 1.1864 - val_main_accuracy: 0.5326 - val_aux2_accuracy: 0.5725
# Epoch 40/100
# 35/35 - 6s - loss: 1.2615 - aux2_loss: 0.8207 - main_loss: 0.6870 - aux1_accuracy: 0.7312 - aux1_loss: 0.7588 - main_accuracy: 0.7530 - aux2_accuracy: 0.7048 - val_loss: 2.7329 - val_aux2_loss: 1.5815 - val_main_loss: 1.7494 - val_aux1_accuracy: 0.5833 - val_aux1_loss: 1.3610 - val_main_accuracy: 0.5109 - val_aux2_accuracy: 0.5399
# Epoch 41/100
# 35/35 - 6s - loss: 1.3691 - aux2_loss: 0.9067 - main_loss: 0.7438 - aux1_accuracy: 0.7030 - aux1_loss: 0.8321 - main_accuracy: 0.7293 - aux2_accuracy: 0.6821 - val_loss: 2.4071 - val_aux2_loss: 1.4439 - val_main_loss: 1.4706 - val_aux1_accuracy: 0.5254 - val_aux1_loss: 1.3330 - val_main_accuracy: 0.4928 - val_aux2_accuracy: 0.5254
# Epoch 42/100
# 35/35 - 6s - loss: 1.2142 - aux2_loss: 0.8079 - main_loss: 0.6452 - aux1_accuracy: 0.7430 - aux1_loss: 0.7452 - main_accuracy: 0.7666 - aux2_accuracy: 0.7012 - val_loss: 2.2693 - val_aux2_loss: 1.3193 - val_main_loss: 1.4051 - val_aux1_accuracy: 0.5797 - val_aux1_loss: 1.2223 - val_main_accuracy: 0.5580 - val_aux2_accuracy: 0.5761
# Epoch 43/100
# 35/35 - 6s - loss: 1.0607 - aux2_loss: 0.6820 - main_loss: 0.5601 - aux1_accuracy: 0.7784 - aux1_loss: 0.6485 - main_accuracy: 0.8102 - aux2_accuracy: 0.7620 - val_loss: 2.2232 - val_aux2_loss: 1.2464 - val_main_loss: 1.3786 - val_aux1_accuracy: 0.6304 - val_aux1_loss: 1.2353 - val_main_accuracy: 0.6232 - val_aux2_accuracy: 0.6123
# Epoch 44/100
# 35/35 - 6s - loss: 1.1033 - aux2_loss: 0.7405 - main_loss: 0.5619 - aux1_accuracy: 0.7439 - aux1_loss: 0.7159 - main_accuracy: 0.8093 - aux2_accuracy: 0.7511 - val_loss: 2.6209 - val_aux2_loss: 1.4494 - val_main_loss: 1.7009 - val_aux1_accuracy: 0.6268 - val_aux1_loss: 1.2600 - val_main_accuracy: 0.6014 - val_aux2_accuracy: 0.5797
# Epoch 45/100
# 35/35 - 6s - loss: 0.9756 - aux2_loss: 0.6668 - main_loss: 0.4727 - aux1_accuracy: 0.7775 - aux1_loss: 0.6408 - main_accuracy: 0.8392 - aux2_accuracy: 0.7539 - val_loss: 2.5332 - val_aux2_loss: 1.4116 - val_main_loss: 1.5996 - val_aux1_accuracy: 0.5725 - val_aux1_loss: 1.3213 - val_main_accuracy: 0.5580 - val_aux2_accuracy: 0.5652
# Epoch 46/100
# 35/35 - 6s - loss: 0.9441 - aux2_loss: 0.6062 - main_loss: 0.4677 - aux1_accuracy: 0.7820 - aux1_loss: 0.6154 - main_accuracy: 0.8401 - aux2_accuracy: 0.8011 - val_loss: 3.2620 - val_aux2_loss: 1.6859 - val_main_loss: 2.2165 - val_aux1_accuracy: 0.5870 - val_aux1_loss: 1.4493 - val_main_accuracy: 0.5507 - val_aux2_accuracy: 0.5507
# Epoch 47/100
# 35/35 - 6s - loss: 0.8088 - aux2_loss: 0.5272 - main_loss: 0.3860 - aux1_accuracy: 0.8129 - aux1_loss: 0.5352 - main_accuracy: 0.8592 - aux2_accuracy: 0.8211 - val_loss: 2.5557 - val_aux2_loss: 1.3450 - val_main_loss: 1.6562 - val_aux1_accuracy: 0.6304 - val_aux1_loss: 1.3112 - val_main_accuracy: 0.5906 - val_aux2_accuracy: 0.5942
# Epoch 48/100
# 35/35 - 6s - loss: 0.8417 - aux2_loss: 0.5816 - main_loss: 0.3868 - aux1_accuracy: 0.7856 - aux1_loss: 0.5939 - main_accuracy: 0.8674 - aux2_accuracy: 0.8074 - val_loss: 3.0722 - val_aux2_loss: 1.7361 - val_main_loss: 1.9823 - val_aux1_accuracy: 0.5217 - val_aux1_loss: 1.5589 - val_main_accuracy: 0.4746 - val_aux2_accuracy: 0.4638
# Epoch 49/100
# 35/35 - 6s - loss: 1.1004 - aux2_loss: 0.7055 - main_loss: 0.6049 - aux1_accuracy: 0.7911 - aux1_loss: 0.6054 - main_accuracy: 0.7911 - aux2_accuracy: 0.7448 - val_loss: 2.6331 - val_aux2_loss: 1.3884 - val_main_loss: 1.7284 - val_aux1_accuracy: 0.6449 - val_aux1_loss: 1.2888 - val_main_accuracy: 0.5833 - val_aux2_accuracy: 0.6341
# Epoch 50/100
# 35/35 - 6s - loss: 0.6907 - aux2_loss: 0.4851 - main_loss: 0.2946 - aux1_accuracy: 0.8374 - aux1_loss: 0.5021 - main_accuracy: 0.9001 - aux2_accuracy: 0.8347 - val_loss: 2.4682 - val_aux2_loss: 1.2986 - val_main_loss: 1.6072 - val_aux1_accuracy: 0.6159 - val_aux1_loss: 1.2439 - val_main_accuracy: 0.6196 - val_aux2_accuracy: 0.6486
# Epoch 51/100
# 35/35 - 6s - loss: 0.6199 - aux2_loss: 0.3902 - main_loss: 0.2758 - aux1_accuracy: 0.8565 - aux1_loss: 0.4313 - main_accuracy: 0.8992 - aux2_accuracy: 0.8565 - val_loss: 2.7553 - val_aux2_loss: 1.4832 - val_main_loss: 1.8350 - val_aux1_accuracy: 0.6268 - val_aux1_loss: 1.2576 - val_main_accuracy: 0.6014 - val_aux2_accuracy: 0.6014
# Epoch 52/100
# 35/35 - 6s - loss: 0.7105 - aux2_loss: 0.4827 - main_loss: 0.3144 - aux1_accuracy: 0.8374 - aux1_loss: 0.4944 - main_accuracy: 0.8955 - aux2_accuracy: 0.8374 - val_loss: 2.5030 - val_aux2_loss: 1.2360 - val_main_loss: 1.6637 - val_aux1_accuracy: 0.6304 - val_aux1_loss: 1.2299 - val_main_accuracy: 0.6304 - val_aux2_accuracy: 0.6449
# Epoch 53/100
# 35/35 - 6s - loss: 0.6307 - aux2_loss: 0.4375 - main_loss: 0.2632 - aux1_accuracy: 0.8392 - aux1_loss: 0.4584 - main_accuracy: 0.9128 - aux2_accuracy: 0.8610 - val_loss: 2.5214 - val_aux2_loss: 1.3211 - val_main_loss: 1.6829 - val_aux1_accuracy: 0.6848 - val_aux1_loss: 1.1577 - val_main_accuracy: 0.6304 - val_aux2_accuracy: 0.6594
# Epoch 54/100
# 35/35 - 6s - loss: 0.4455 - aux2_loss: 0.2996 - main_loss: 0.1598 - aux1_accuracy: 0.8919 - aux1_loss: 0.3369 - main_accuracy: 0.9464 - aux2_accuracy: 0.8965 - val_loss: 2.6497 - val_aux2_loss: 1.1571 - val_main_loss: 1.8645 - val_aux1_accuracy: 0.6739 - val_aux1_loss: 1.1387 - val_main_accuracy: 0.6522 - val_aux2_accuracy: 0.6703
# Epoch 55/100
# 35/35 - 6s - loss: 0.5234 - aux2_loss: 0.3484 - main_loss: 0.2167 - aux1_accuracy: 0.8910 - aux1_loss: 0.3534 - main_accuracy: 0.9310 - aux2_accuracy: 0.8837 - val_loss: 3.1366 - val_aux2_loss: 1.4530 - val_main_loss: 2.2060 - val_aux1_accuracy: 0.6630 - val_aux1_loss: 1.3325 - val_main_accuracy: 0.6159 - val_aux2_accuracy: 0.6341
# Epoch 56/100
# 35/35 - 6s - loss: 0.5290 - aux2_loss: 0.3493 - main_loss: 0.2184 - aux1_accuracy: 0.8774 - aux1_loss: 0.3621 - main_accuracy: 0.9292 - aux2_accuracy: 0.8910 - val_loss: 2.5035 - val_aux2_loss: 1.2711 - val_main_loss: 1.7064 - val_aux1_accuracy: 0.7210 - val_aux1_loss: 1.0622 - val_main_accuracy: 0.6558 - val_aux2_accuracy: 0.6739
# Epoch 57/100
# 35/35 - 6s - loss: 0.3646 - aux2_loss: 0.2349 - main_loss: 0.1066 - aux1_accuracy: 0.8965 - aux1_loss: 0.3055 - main_accuracy: 0.9682 - aux2_accuracy: 0.9273 - val_loss: 3.0984 - val_aux2_loss: 1.6183 - val_main_loss: 2.1372 - val_aux1_accuracy: 0.6703 - val_aux1_loss: 1.2722 - val_main_accuracy: 0.6341 - val_aux2_accuracy: 0.6413
# Epoch 58/100
# 35/35 - 6s - loss: 0.5640 - aux2_loss: 0.3878 - main_loss: 0.2419 - aux1_accuracy: 0.8792 - aux1_loss: 0.3739 - main_accuracy: 0.9210 - aux2_accuracy: 0.8819 - val_loss: 3.1088 - val_aux2_loss: 1.4319 - val_main_loss: 2.1483 - val_aux1_accuracy: 0.6739 - val_aux1_loss: 1.4605 - val_main_accuracy: 0.6196 - val_aux2_accuracy: 0.6486
# Epoch 59/100
# 35/35 - 6s - loss: 0.3736 - aux2_loss: 0.2860 - main_loss: 0.1100 - aux1_accuracy: 0.9083 - aux1_loss: 0.2814 - main_accuracy: 0.9646 - aux2_accuracy: 0.9074 - val_loss: 2.6680 - val_aux2_loss: 1.2220 - val_main_loss: 1.7903 - val_aux1_accuracy: 0.6558 - val_aux1_loss: 1.3944 - val_main_accuracy: 0.6449 - val_aux2_accuracy: 0.6884
# Epoch 60/100
# 35/35 - 6s - loss: 0.3209 - aux2_loss: 0.1951 - main_loss: 0.0841 - aux1_accuracy: 0.9137 - aux1_loss: 0.2839 - main_accuracy: 0.9737 - aux2_accuracy: 0.9346 - val_loss: 3.6151 - val_aux2_loss: 1.6274 - val_main_loss: 2.6400 - val_aux1_accuracy: 0.6522 - val_aux1_loss: 1.3175 - val_main_accuracy: 0.6087 - val_aux2_accuracy: 0.6051
# Epoch 61/100
# 35/35 - 6s - loss: 0.3733 - aux2_loss: 0.2287 - main_loss: 0.1295 - aux1_accuracy: 0.9119 - aux1_loss: 0.2797 - main_accuracy: 0.9609 - aux2_accuracy: 0.9319 - val_loss: 2.7762 - val_aux2_loss: 1.4334 - val_main_loss: 1.8855 - val_aux1_accuracy: 0.6667 - val_aux1_loss: 1.2271 - val_main_accuracy: 0.6594 - val_aux2_accuracy: 0.6594
# Epoch 62/100
# 35/35 - 6s - loss: 0.4759 - aux2_loss: 0.2857 - main_loss: 0.2066 - aux1_accuracy: 0.9210 - aux1_loss: 0.2893 - main_accuracy: 0.9246 - aux2_accuracy: 0.9110 - val_loss: 3.5085 - val_aux2_loss: 1.5854 - val_main_loss: 2.5030 - val_aux1_accuracy: 0.6377 - val_aux1_loss: 1.4462 - val_main_accuracy: 0.6087 - val_aux2_accuracy: 0.6268
# Epoch 63/100
# 35/35 - 6s - loss: 0.3452 - aux2_loss: 0.2241 - main_loss: 0.1111 - aux1_accuracy: 0.9101 - aux1_loss: 0.2436 - main_accuracy: 0.9619 - aux2_accuracy: 0.9292 - val_loss: 2.9652 - val_aux2_loss: 1.4064 - val_main_loss: 2.0689 - val_aux1_accuracy: 0.6993 - val_aux1_loss: 1.2566 - val_main_accuracy: 0.6304 - val_aux2_accuracy: 0.6630
# Epoch 64/100
# 35/35 - 6s - loss: 0.2037 - aux2_loss: 0.1195 - main_loss: 0.0236 - aux1_accuracy: 0.9473 - aux1_loss: 0.1654 - main_accuracy: 0.9946 - aux2_accuracy: 0.9691 - val_loss: 3.5895 - val_aux2_loss: 1.6300 - val_main_loss: 2.6398 - val_aux1_accuracy: 0.7174 - val_aux1_loss: 1.2447 - val_main_accuracy: 0.6377 - val_aux2_accuracy: 0.6703
# Epoch 65/100
# 35/35 - 6s - loss: 0.1596 - aux2_loss: 0.0806 - main_loss: 0.0129 - aux1_accuracy: 0.9655 - aux1_loss: 0.1283 - main_accuracy: 0.9973 - aux2_accuracy: 0.9709 - val_loss: 3.8499 - val_aux2_loss: 1.7328 - val_main_loss: 2.8169 - val_aux1_accuracy: 0.7138 - val_aux1_loss: 1.4370 - val_main_accuracy: 0.6341 - val_aux2_accuracy: 0.6522
# Epoch 66/100
# 35/35 - 6s - loss: 0.1917 - aux2_loss: 0.1110 - main_loss: 0.0262 - aux1_accuracy: 0.9455 - aux1_loss: 0.1631 - main_accuracy: 0.9927 - aux2_accuracy: 0.9609 - val_loss: 4.8351 - val_aux2_loss: 1.9586 - val_main_loss: 3.6583 - val_aux1_accuracy: 0.6522 - val_aux1_loss: 1.6860 - val_main_accuracy: 0.6159 - val_aux2_accuracy: 0.6413
# Epoch 67/100
# 35/35 - 6s - loss: 0.5517 - aux2_loss: 0.3111 - main_loss: 0.2677 - aux1_accuracy: 0.8774 - aux1_loss: 0.3328 - main_accuracy: 0.9310 - aux2_accuracy: 0.9074 - val_loss: 2.8406 - val_aux2_loss: 1.6077 - val_main_loss: 1.8026 - val_aux1_accuracy: 0.6775 - val_aux1_loss: 1.5317 - val_main_accuracy: 0.6522 - val_aux2_accuracy: 0.6413
# Epoch 68/100
# 35/35 - 6s - loss: 0.3412 - aux2_loss: 0.2165 - main_loss: 0.1134 - aux1_accuracy: 0.9146 - aux1_loss: 0.2289 - main_accuracy: 0.9673 - aux2_accuracy: 0.9391 - val_loss: 3.2892 - val_aux2_loss: 1.6345 - val_main_loss: 2.2319 - val_aux1_accuracy: 0.6486 - val_aux1_loss: 1.5899 - val_main_accuracy: 0.6594 - val_aux2_accuracy: 0.6630
# Epoch 69/100
# 35/35 - 6s - loss: 0.2405 - aux2_loss: 0.1449 - main_loss: 0.0566 - aux1_accuracy: 0.9491 - aux1_loss: 0.1768 - main_accuracy: 0.9827 - aux2_accuracy: 0.9609 - val_loss: 3.1172 - val_aux2_loss: 1.5550 - val_main_loss: 2.1518 - val_aux1_accuracy: 0.6812 - val_aux1_loss: 1.3668 - val_main_accuracy: 0.6739 - val_aux2_accuracy: 0.6486
# Epoch 70/100
# 35/35 - 6s - loss: 0.2341 - aux2_loss: 0.1588 - main_loss: 0.0504 - aux1_accuracy: 0.9555 - aux1_loss: 0.1634 - main_accuracy: 0.9818 - aux2_accuracy: 0.9500 - val_loss: 4.0418 - val_aux2_loss: 1.8206 - val_main_loss: 2.9735 - val_aux1_accuracy: 0.6957 - val_aux1_loss: 1.4505 - val_main_accuracy: 0.6413 - val_aux2_accuracy: 0.6630
# Epoch 71/100
# 35/35 - 6s - loss: 0.2453 - aux2_loss: 0.1264 - main_loss: 0.0682 - aux1_accuracy: 0.9428 - aux1_loss: 0.1797 - main_accuracy: 0.9773 - aux2_accuracy: 0.9591 - val_loss: 2.7870 - val_aux2_loss: 1.3340 - val_main_loss: 1.9357 - val_aux1_accuracy: 0.6812 - val_aux1_loss: 1.2256 - val_main_accuracy: 0.6703 - val_aux2_accuracy: 0.6667
# Epoch 72/100
# 35/35 - 6s - loss: 0.3251 - aux2_loss: 0.2010 - main_loss: 0.1129 - aux1_accuracy: 0.9355 - aux1_loss: 0.2002 - main_accuracy: 0.9637 - aux2_accuracy: 0.9346 - val_loss: 2.8702 - val_aux2_loss: 1.3237 - val_main_loss: 1.9825 - val_aux1_accuracy: 0.6993 - val_aux1_loss: 1.3108 - val_main_accuracy: 0.6630 - val_aux2_accuracy: 0.6993
# Epoch 73/100
# 35/35 - 6s - loss: 0.3844 - aux2_loss: 0.2573 - main_loss: 0.1517 - aux1_accuracy: 0.9228 - aux1_loss: 0.2079 - main_accuracy: 0.9619 - aux2_accuracy: 0.9228 - val_loss: 2.7577 - val_aux2_loss: 1.4941 - val_main_loss: 1.7923 - val_aux1_accuracy: 0.6775 - val_aux1_loss: 1.4185 - val_main_accuracy: 0.6594 - val_aux2_accuracy: 0.6377
# Epoch 74/100
# 35/35 - 6s - loss: 0.3033 - aux2_loss: 0.1677 - main_loss: 0.0973 - aux1_accuracy: 0.9310 - aux1_loss: 0.2198 - main_accuracy: 0.9673 - aux2_accuracy: 0.9455 - val_loss: 2.4604 - val_aux2_loss: 1.2552 - val_main_loss: 1.6373 - val_aux1_accuracy: 0.7283 - val_aux1_loss: 1.2008 - val_main_accuracy: 0.6703 - val_aux2_accuracy: 0.6920
# Epoch 75/100
# 35/35 - 6s - loss: 0.2010 - aux2_loss: 0.1283 - main_loss: 0.0391 - aux1_accuracy: 0.9628 - aux1_loss: 0.1301 - main_accuracy: 0.9882 - aux2_accuracy: 0.9609 - val_loss: 3.2381 - val_aux2_loss: 1.5867 - val_main_loss: 2.2273 - val_aux1_accuracy: 0.7065 - val_aux1_loss: 1.5062 - val_main_accuracy: 0.6703 - val_aux2_accuracy: 0.6812
# Epoch 76/100
# 35/35 - 6s - loss: 0.1420 - aux2_loss: 0.0729 - main_loss: 0.0074 - aux1_accuracy: 0.9691 - aux1_loss: 0.1027 - main_accuracy: 0.9991 - aux2_accuracy: 0.9755 - val_loss: 3.3822 - val_aux2_loss: 1.5915 - val_main_loss: 2.4104 - val_aux1_accuracy: 0.6993 - val_aux1_loss: 1.3817 - val_main_accuracy: 0.6957 - val_aux2_accuracy: 0.7029
# Epoch 77/100
# 35/35 - 6s - loss: 0.1326 - aux2_loss: 0.0476 - main_loss: 0.0201 - aux1_accuracy: 0.9791 - aux1_loss: 0.0696 - main_accuracy: 0.9946 - aux2_accuracy: 0.9864 - val_loss: 3.7011 - val_aux2_loss: 1.4726 - val_main_loss: 2.7770 - val_aux1_accuracy: 0.7283 - val_aux1_loss: 1.3572 - val_main_accuracy: 0.6703 - val_aux2_accuracy: 0.6957
# Epoch 78/100
# 35/35 - 6s - loss: 0.4666 - aux2_loss: 0.2975 - main_loss: 0.2256 - aux1_accuracy: 0.9155 - aux1_loss: 0.2376 - main_accuracy: 0.9292 - aux2_accuracy: 0.9101 - val_loss: 2.9271 - val_aux2_loss: 1.3411 - val_main_loss: 1.9749 - val_aux1_accuracy: 0.6775 - val_aux1_loss: 1.5395 - val_main_accuracy: 0.6449 - val_aux2_accuracy: 0.6196
# Epoch 79/100
# 35/35 - 6s - loss: 0.3477 - aux2_loss: 0.1881 - main_loss: 0.1206 - aux1_accuracy: 0.9201 - aux1_loss: 0.2645 - main_accuracy: 0.9582 - aux2_accuracy: 0.9391 - val_loss: 2.6931 - val_aux2_loss: 1.5215 - val_main_loss: 1.7397 - val_aux1_accuracy: 0.7174 - val_aux1_loss: 1.3609 - val_main_accuracy: 0.6884 - val_aux2_accuracy: 0.6993
# Epoch 80/100
# 35/35 - 6s - loss: 0.1731 - aux2_loss: 0.0990 - main_loss: 0.0236 - aux1_accuracy: 0.9673 - aux1_loss: 0.1060 - main_accuracy: 0.9964 - aux2_accuracy: 0.9646 - val_loss: 3.1899 - val_aux2_loss: 1.4786 - val_main_loss: 2.2449 - val_aux1_accuracy: 0.7246 - val_aux1_loss: 1.3948 - val_main_accuracy: 0.6703 - val_aux2_accuracy: 0.6920
# Epoch 81/100
# 35/35 - 6s - loss: 0.1143 - aux2_loss: 0.0481 - main_loss: 0.0058 - aux1_accuracy: 0.9818 - aux1_loss: 0.0590 - main_accuracy: 0.9973 - aux2_accuracy: 0.9855 - val_loss: 3.4202 - val_aux2_loss: 1.5564 - val_main_loss: 2.4452 - val_aux1_accuracy: 0.7065 - val_aux1_loss: 1.4523 - val_main_accuracy: 0.6594 - val_aux2_accuracy: 0.6884
# Epoch 82/100
# 35/35 - 6s - loss: 0.1065 - aux2_loss: 0.0498 - main_loss: 0.0014 - aux1_accuracy: 0.9846 - aux1_loss: 0.0588 - main_accuracy: 1.0000 - aux2_accuracy: 0.9882 - val_loss: 3.2940 - val_aux2_loss: 1.4924 - val_main_loss: 2.3724 - val_aux1_accuracy: 0.7283 - val_aux1_loss: 1.3389 - val_main_accuracy: 0.6812 - val_aux2_accuracy: 0.6993
# Epoch 83/100
# 35/35 - 6s - loss: 0.0888 - aux2_loss: 0.0212 - main_loss: 2.6592e-04 - aux1_accuracy: 0.9918 - aux1_loss: 0.0421 - main_accuracy: 1.0000 - aux2_accuracy: 0.9946 - val_loss: 3.5103 - val_aux2_loss: 1.5630 - val_main_loss: 2.5466 - val_aux1_accuracy: 0.7246 - val_aux1_loss: 1.4247 - val_main_accuracy: 0.6920 - val_aux2_accuracy: 0.7065
# Epoch 84/100
# 35/35 - 6s - loss: 0.0879 - aux2_loss: 0.0342 - main_loss: 1.7375e-04 - aux1_accuracy: 0.9900 - aux1_loss: 0.0387 - main_accuracy: 1.0000 - aux2_accuracy: 0.9918 - val_loss: 3.7105 - val_aux2_loss: 1.6853 - val_main_loss: 2.7101 - val_aux1_accuracy: 0.7210 - val_aux1_loss: 1.4285 - val_main_accuracy: 0.6812 - val_aux2_accuracy: 0.7065
# Epoch 85/100
# 35/35 - 6s - loss: 0.0857 - aux2_loss: 0.0257 - main_loss: 1.3235e-04 - aux1_accuracy: 0.9891 - aux1_loss: 0.0420 - main_accuracy: 1.0000 - aux2_accuracy: 0.9927 - val_loss: 3.8173 - val_aux2_loss: 1.6316 - val_main_loss: 2.8341 - val_aux1_accuracy: 0.7391 - val_aux1_loss: 1.4351 - val_main_accuracy: 0.6920 - val_aux2_accuracy: 0.7138
# Epoch 86/100
# 35/35 - 6s - loss: 0.0885 - aux2_loss: 0.0277 - main_loss: 1.0112e-04 - aux1_accuracy: 0.9846 - aux1_loss: 0.0515 - main_accuracy: 1.0000 - aux2_accuracy: 0.9900 - val_loss: 3.9485 - val_aux2_loss: 1.7974 - val_main_loss: 2.9324 - val_aux1_accuracy: 0.7210 - val_aux1_loss: 1.3621 - val_main_accuracy: 0.6920 - val_aux2_accuracy: 0.6957
# Epoch 87/100
# 35/35 - 6s - loss: 0.0930 - aux2_loss: 0.0346 - main_loss: 1.1995e-04 - aux1_accuracy: 0.9900 - aux1_loss: 0.0384 - main_accuracy: 1.0000 - aux2_accuracy: 0.9873 - val_loss: 4.4736 - val_aux2_loss: 1.7136 - val_main_loss: 3.4670 - val_aux1_accuracy: 0.7319 - val_aux1_loss: 1.3911 - val_main_accuracy: 0.6775 - val_aux2_accuracy: 0.6957
# Epoch 88/100
# 35/35 - 6s - loss: 0.1565 - aux2_loss: 0.0738 - main_loss: 0.0368 - aux1_accuracy: 0.9773 - aux1_loss: 0.0892 - main_accuracy: 0.9864 - aux2_accuracy: 0.9755 - val_loss: 3.6233 - val_aux2_loss: 1.5438 - val_main_loss: 2.6966 - val_aux1_accuracy: 0.6957 - val_aux1_loss: 1.3050 - val_main_accuracy: 0.6630 - val_aux2_accuracy: 0.6812
# Epoch 89/100
# 35/35 - 6s - loss: 0.4130 - aux2_loss: 0.1912 - main_loss: 0.2002 - aux1_accuracy: 0.9210 - aux1_loss: 0.2592 - main_accuracy: 0.9410 - aux2_accuracy: 0.9419 - val_loss: 3.0913 - val_aux2_loss: 1.5509 - val_main_loss: 2.0899 - val_aux1_accuracy: 0.6703 - val_aux1_loss: 1.5038 - val_main_accuracy: 0.6051 - val_aux2_accuracy: 0.6341
# Epoch 90/100
# 35/35 - 6s - loss: 0.3042 - aux2_loss: 0.1767 - main_loss: 0.1069 - aux1_accuracy: 0.9373 - aux1_loss: 0.1872 - main_accuracy: 0.9664 - aux2_accuracy: 0.9391 - val_loss: 2.8179 - val_aux2_loss: 1.4173 - val_main_loss: 1.8873 - val_aux1_accuracy: 0.6957 - val_aux1_loss: 1.3843 - val_main_accuracy: 0.6558 - val_aux2_accuracy: 0.6775
# Epoch 91/100
# 35/35 - 6s - loss: 0.2204 - aux2_loss: 0.1296 - main_loss: 0.0572 - aux1_accuracy: 0.9646 - aux1_loss: 0.1322 - main_accuracy: 0.9827 - aux2_accuracy: 0.9664 - val_loss: 3.4413 - val_aux2_loss: 1.8011 - val_main_loss: 2.3148 - val_aux1_accuracy: 0.6667 - val_aux1_loss: 1.6781 - val_main_accuracy: 0.6123 - val_aux2_accuracy: 0.6232
# Epoch 92/100
# 35/35 - 6s - loss: 0.2415 - aux2_loss: 0.1323 - main_loss: 0.0719 - aux1_accuracy: 0.9546 - aux1_loss: 0.1506 - main_accuracy: 0.9782 - aux2_accuracy: 0.9646 - val_loss: 3.2771 - val_aux2_loss: 1.6576 - val_main_loss: 2.2629 - val_aux1_accuracy: 0.6993 - val_aux1_loss: 1.4512 - val_main_accuracy: 0.6341 - val_aux2_accuracy: 0.6558
# Epoch 93/100
# 35/35 - 6s - loss: 0.1844 - aux2_loss: 0.1077 - main_loss: 0.0448 - aux1_accuracy: 0.9728 - aux1_loss: 0.0973 - main_accuracy: 0.9855 - aux2_accuracy: 0.9673 - val_loss: 3.9627 - val_aux2_loss: 1.9833 - val_main_loss: 2.7581 - val_aux1_accuracy: 0.6812 - val_aux1_loss: 1.7852 - val_main_accuracy: 0.6413 - val_aux2_accuracy: 0.6703
# Epoch 94/100
# 35/35 - 6s - loss: 0.1256 - aux2_loss: 0.0635 - main_loss: 0.0112 - aux1_accuracy: 0.9737 - aux1_loss: 0.0777 - main_accuracy: 0.9964 - aux2_accuracy: 0.9773 - val_loss: 3.7533 - val_aux2_loss: 1.7546 - val_main_loss: 2.7290 - val_aux1_accuracy: 0.7029 - val_aux1_loss: 1.4258 - val_main_accuracy: 0.6486 - val_aux2_accuracy: 0.6920
# Epoch 95/100
# 35/35 - 6s - loss: 0.0939 - aux2_loss: 0.0267 - main_loss: 0.0030 - aux1_accuracy: 0.9873 - aux1_loss: 0.0507 - main_accuracy: 0.9991 - aux2_accuracy: 0.9955 - val_loss: 3.4900 - val_aux2_loss: 1.7412 - val_main_loss: 2.4495 - val_aux1_accuracy: 0.7101 - val_aux1_loss: 1.5048 - val_main_accuracy: 0.6775 - val_aux2_accuracy: 0.7065
# Epoch 96/100
# 35/35 - 6s - loss: 0.0914 - aux2_loss: 0.0356 - main_loss: 5.0875e-04 - aux1_accuracy: 0.9873 - aux1_loss: 0.0428 - main_accuracy: 1.0000 - aux2_accuracy: 0.9900 - val_loss: 3.6369 - val_aux2_loss: 1.6811 - val_main_loss: 2.6348 - val_aux1_accuracy: 0.7210 - val_aux1_loss: 1.4381 - val_main_accuracy: 0.6848 - val_aux2_accuracy: 0.6993
# Epoch 97/100
# 35/35 - 6s - loss: 0.0830 - aux2_loss: 0.0234 - main_loss: 2.2010e-04 - aux1_accuracy: 0.9909 - aux1_loss: 0.0400 - main_accuracy: 1.0000 - aux2_accuracy: 0.9955 - val_loss: 3.7093 - val_aux2_loss: 1.7936 - val_main_loss: 2.6872 - val_aux1_accuracy: 0.7138 - val_aux1_loss: 1.4092 - val_main_accuracy: 0.6739 - val_aux2_accuracy: 0.7246
# Epoch 98/100
# 35/35 - 6s - loss: 0.0772 - aux2_loss: 0.0303 - main_loss: 2.5645e-04 - aux1_accuracy: 0.9973 - aux1_loss: 0.0271 - main_accuracy: 1.0000 - aux2_accuracy: 0.9909 - val_loss: 3.9639 - val_aux2_loss: 1.7469 - val_main_loss: 2.9298 - val_aux1_accuracy: 0.7174 - val_aux1_loss: 1.5021 - val_main_accuracy: 0.6775 - val_aux2_accuracy: 0.6957
# Epoch 99/100
# 35/35 - 6s - loss: 0.0739 - aux2_loss: 0.0293 - main_loss: 1.2271e-04 - aux1_accuracy: 0.9973 - aux1_loss: 0.0240 - main_accuracy: 1.0000 - aux2_accuracy: 0.9936 - val_loss: 3.9927 - val_aux2_loss: 1.7216 - val_main_loss: 2.9588 - val_aux1_accuracy: 0.7210 - val_aux1_loss: 1.5380 - val_main_accuracy: 0.6957 - val_aux2_accuracy: 0.6884
# Epoch 100/100
# 35/35 - 6s - loss: 0.0735 - aux2_loss: 0.0175 - main_loss: 1.7123e-04 - aux1_accuracy: 0.9918 - aux1_loss: 0.0340 - main_accuracy: 1.0000 - aux2_accuracy: 0.9964 - val_loss: 4.1137 - val_aux2_loss: 1.6415 - val_main_loss: 3.1033 - val_aux1_accuracy: 0.7065 - val_aux1_loss: 1.5364 - val_main_accuracy: 0.6812 - val_aux2_accuracy: 0.6848

# %%
model_json = model.to_json()
with open("GoogleNet_architecture.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("GoogleNet_weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(["train", "test"], loc = "upper left")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot(model.history.history["main_accuracy"])
plt.plot(model.history.history["val_main_accuracy"])
plt.title("Model accuracy")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(["train", "test"], loc = "upper left")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
model.summary()
# Out:
# Model: "GoogleNet_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_LRN (TensorFlowOpLa [(None, 56, 56, 64)] 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   4160        tf_op_layer_LRN[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 192)  110784      activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 192)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_LRN_1 (TensorFlowOp [(None, 56, 56, 192) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 27, 27, 192)  0           tf_op_layer_LRN_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 27, 27, 96)   18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 27, 27, 16)   3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 27, 27, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 27, 27, 96)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 27, 27, 16)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 27, 27, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 27, 27, 64)   12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 27, 27, 128)  110720      activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 27, 27, 32)   12832       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 27, 27, 32)   6176        activation_8[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 27, 27, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 27, 27, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 27, 27, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 27, 27, 32)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 27, 27, 256)  0           activation_3[0][0]
#                                                                  activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 27, 27, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 27, 27, 32)   8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 27, 27, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 27, 27, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 27, 27, 32)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 27, 27, 256)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 27, 27, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 27, 27, 192)  221376      activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 27, 27, 96)   76896       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 27, 27, 64)   16448       activation_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 27, 27, 128)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 27, 27, 192)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 27, 27, 96)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 27, 27, 64)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 27, 27, 480)  0           activation_10[0][0]
#                                                                  activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 480)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 96)   46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 16)   7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 480)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 14, 14, 96)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 14, 16)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 14, 14, 480)  0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 192)  92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 208)  179920      activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 48)   19248       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 64)   30784       activation_22[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 14, 14, 192)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 14, 14, 208)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 14, 48)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 64)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 512)  0           activation_17[0][0]
#                                                                  activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 112)  57456       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 24)   12312       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 112)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 24)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 512)  0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 160)  82080       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 224)  226016      activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 64)   38464       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 64)   32832       activation_29[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 160)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 224)  0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 64)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 64)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 512)  0           activation_24[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_28[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 128)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 24)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 512)  0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 256)  295168      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 64)   38464       activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 64)   32832       activation_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 128)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 256)  0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 64)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 64)   0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 512)  0           activation_31[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_35[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 144)  73872       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 32)   16416       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 144)  0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 32)   0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 14, 14, 512)  0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 112)  57456       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 288)  373536      activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 64)   51264       activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 64)   32832       activation_43[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 112)  0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 288)  0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 64)   0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 14, 14, 64)   0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 528)  0           activation_38[0][0]
#                                                                  activation_40[0][0]
#                                                                  activation_42[0][0]
#                                                                  activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 160)  84640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 32)   16928       concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 528)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 14, 14, 160)  0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 14, 14, 32)   0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 14, 14, 528)  0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 256)  135424      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 320)  461120      activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 128)  102528      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 128)  67712       activation_50[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 14, 14, 256)  0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 14, 14, 320)  0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 14, 14, 128)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 14, 14, 128)  0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 832)  0           activation_45[0][0]
#                                                                  activation_47[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 160)    133280      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 32)     26656       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 7, 7, 832)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 7, 7, 160)    0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 7, 7, 32)     0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 7, 7, 832)    0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 256)    213248      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 320)    461120      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 128)    102528      activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 128)    106624      activation_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 7, 7, 256)    0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 7, 7, 320)    0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 7, 7, 128)    0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 7, 7, 128)    0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 832)    0           activation_52[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_56[0][0]
#                                                                  activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 192)    159936      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 48)     39984       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 7, 7, 192)    0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 7, 7, 48)     0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 7, 7, 832)    0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 384)    319872      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 384)    663936      activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 128)    153728      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 128)    106624      activation_64[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 7, 7, 384)    0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 7, 7, 384)    0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 7, 7, 128)    0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 7, 7, 128)    0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 4, 4, 512)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 528)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 1024)   0           activation_59[0][0]
#                                                                  activation_61[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 128)    65664       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 128)    67712       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 1024)   0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1024)         0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     flatten[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          1049088     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          524800      flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        dropout[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           5130        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           5130        dropout_2[0][0]
# __________________________________________________________________________________________________
# aux1 (Activation)               (None, 10)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# aux2 (Activation)               (None, 10)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# main (Activation)               (None, 10)           0           dense_5[0][0]
# ==================================================================================================
# Total params: 8,745,294
# Trainable params: 8,745,294
# Non-trainable params: 0
# __________________________________________________________________________________________________
